# %%
'''
Напишите программу, которая симулирует лотерею:

Генерирует список из 50 случайных чисел от 1 до 100.
Перемешивает его.
Выбирает 5 случайных чисел без повторений.
Выводит результат на экран.
'''
from random import randint, shuffle, sample

kucha = []
[kucha.append(randint(1, 100)) for _ in range(100)]
shuffle(kucha)

print(sample(kucha, 5))
# Out:
# [19, 2, 53, 25, 75]

# %%
'''
Напишите программу, которая:

Создаёт папку test_directory, если её нет.
Внутри создаёт файл info.txt и записывает туда строку "Этот файл создан автоматически."
Проверяет, существует ли файл.
Если существует – считывает его содержимое и выводит в консоль.
'''
from pathlib import

p = './test_directory'
if
